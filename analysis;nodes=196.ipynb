# %% [markdown]
# # Experiments analysis

# %%
import msgpack
import edge_sim_py
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import matplotlib.ticker as mtick
import scipy.stats as stats

pd.options.display.max_colwidth = 200

# %% [markdown]
# ## Base functions

# %% [markdown]
# ### Latency

# %%
def get_latency_data(user_type=None):
    user_data = []

    for log in logs:
        simulation_data = {
            "dataset": log,
            "mean": 0,
            "median": 0,
            "p95": 0,
            "geo_mean": 0,
        }

        # Opening file
        user_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/User.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/User.msgpack"
        )
        user_file = open(user_msgpack_file, "rb")
        user_msgpack = msgpack.load(user_file)
        user_df = pd.DataFrame(user_msgpack)

        # Collecting information
        latency = (
            user_df[["Object", "Delays"]]
            if user_type is None
            else user_df[user_df["User Type"] == user_type][["Object", "Delays"]]
        )

        # Persisting information
        simulation_data["mean"] = latency["Delays"].mean()
        simulation_data["median"] = latency["Delays"].median()
        simulation_data["p95"] = latency["Delays"].quantile(0.95)
        simulation_data["geo_mean"] = stats.gmean(latency["Delays"])

        # Closing file
        user_file.close()

        # Appending data
        user_data.append(simulation_data)

    return pd.DataFrame(user_data)

# %% [markdown]
# ### Provisioning Time

# %%
def get_provisioning_time_data(step):
    service_data = []

    for log in logs:
        simulation_data = {
            "dataset": log,
            "mean": 0,
            "median": 0,
            "p95": 0,
            "mean (w/o cache)": 0,
            "geo_mean (w/o cache)": 0,
            "old_mean": 0,
        }

        # Opening file
        service_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/Service.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/Service.msgpack"
        )
        service_file = open(service_msgpack_file, "rb")
        service_msgpack = msgpack.load(service_file)
        service_df = pd.DataFrame(service_msgpack)

        # Collecting information
        migrations_duration = service_df[service_df["Time Step"] == step]["Migrations Duration"].apply(pd.Series).stack().reset_index(drop=True)
        migrations_without_cache_duration = service_df[service_df["Time Step"] == step]["Migrations Without Cache Duration"].apply(pd.Series).stack().reset_index(drop=True)
        mean_migration_duration = service_df[service_df["Time Step"] == step]["Migrations Duration"].apply(lambda x: sum(x) / len(x) if len(x) > 0 else 0)

        # Persisting information
        simulation_data["mean"] = migrations_duration.mean()
        simulation_data["median"] = migrations_duration.median()
        simulation_data["p95"] = migrations_duration.quantile(0.95)
        simulation_data["mean (w/o cache)"] = migrations_without_cache_duration.mean()
        simulation_data["geo_mean (w/o cache)"] = stats.gmean(migrations_without_cache_duration)
        simulation_data["old_mean"] = mean_migration_duration.mean()

        # Closing file
        service_file.close()

        # Appending data
        service_data.append(simulation_data)

    return pd.DataFrame(service_data)

# %% [markdown]
# ### Service Reallocations

# %%
def get_reallocations_data(step):
    service_data = []

    for log in logs:
        simulation_data = {
            "dataset": log,
            "total": 0,
            "w/o cache": 0,
        }

        # Opening file
        service_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/Service.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/Service.msgpack"
        )
        service_file = open(service_msgpack_file, "rb")
        service_msgpack = msgpack.load(service_file)
        service_df = pd.DataFrame(service_msgpack)

        # Collecting information
        migrations_last_step = service_df[service_df["Time Step"] == step][["Object", "Number of Finished Migrations", "Number of Finished Migrations Without Using Cache"]]

        # Persisting information
        simulation_data[f"total"] = migrations_last_step["Number of Finished Migrations"].sum()
        simulation_data[f"w/o cache"] = migrations_last_step["Number of Finished Migrations Without Using Cache"].sum()

        # Closing file
        service_file.close()

        # Appending data
        service_data.append(simulation_data)

    return pd.DataFrame(service_data)

# %% [markdown]
# ### Registry Usage

# %%
def get_registry_usage_data():
    registry_data = []

    for log in logs:
        simulation_data = {
            "dataset": log,
            "mean": 0,
            "median": 0,
            "p95": 0,
        }

        # Opening file
        registry_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/ContainerRegistry.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/ContainerRegistry.msgpack"
        )
        registry_file = open(registry_msgpack_file, "rb")
        registry_msgpack = msgpack.load(registry_file)
        registry_df = pd.DataFrame(registry_msgpack)

        # Collecting information
        registry_filtered_data = (
            registry_df[registry_df["P2P"] == True][["Object", "Provisioning", "Not Provisioning"]]
            if log[1] == "p2p"
            else registry_df[["Object", "Provisioning", "Not Provisioning"]]
        )
        registry_data_grouped = registry_filtered_data.groupby("Object").sum()
        registry_data_grouped["Total Steps"] = registry_data_grouped.sum(axis=1)
        registry_data_grouped["Provisioning Percentage"] = registry_data_grouped["Provisioning"] / registry_data_grouped["Total Steps"]
        registry_data_grouped["Not Provisioning Percentage"] = registry_data_grouped["Not Provisioning"] / registry_data_grouped["Total Steps"]

        # Persisting information
        simulation_data["mean"] = registry_data_grouped["Provisioning Percentage"].mean()
        simulation_data["median"] = registry_data_grouped["Provisioning Percentage"].median()
        simulation_data["p95"] = registry_data_grouped["Provisioning Percentage"].quantile(0.95)

        # Closing file
        registry_file.close()

        # Appending data
        registry_data.append(simulation_data)

    return pd.DataFrame(registry_data)

# %% [markdown]
# ### Number of Registries per Time Step

# %%
def get_number_of_registries_data():
    registry_data = {}

    for index, log in enumerate(logs[:4]):
        # Opening file
        registry_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/ContainerRegistry.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/ContainerRegistry.msgpack"
        )
        registry_file = open(registry_msgpack_file, "rb")
        registry_msgpack = msgpack.load(registry_file)
        registry_df = pd.DataFrame(registry_msgpack)

        # Collecting information
        registries_per_timestep = registry_df[registry_df["Time Step"] > 0].groupby(["Time Step"]).count()["Object"]

        # Persisting information
        registry_data[labels[index].capitalize()] = registries_per_timestep

        # Closing file
        registry_file.close()

    registries_per_timestep_df = pd.concat(registry_data, axis=1)

    return registries_per_timestep_df

# %% [markdown]
# ### Server Utilization per Time Step

# %%
def normalize_cpu_and_memory(cpu, memory) -> float:
    """Normalizes the CPU and memory values.

    Args:
        cpu (float): CPU value.
        memory (float): Memory value.

    Returns:
        normalized_value (float): Normalized value.
    """
    normalized_value = (cpu * memory) ** (1 / 2)
    return normalized_value

def get_server_utilization_data():
    server_data = {}

    for index, log in enumerate(logs[:4]):
        # Opening file
        server_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/EdgeServer.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/EdgeServer.msgpack"
        )
        server_file = open(server_msgpack_file, "rb")
        server_msgpack = msgpack.load(server_file)
        server_df = pd.DataFrame(server_msgpack)

        # Collecting information
        server_df = server_df[["Object", "CPU", "RAM", "CPU Demand", "RAM Demand", "Time Step"]]
        server_df["Normalized Utilization"] = server_df.apply(lambda row: normalize_cpu_and_memory(row["CPU Demand"], row["RAM Demand"])/normalize_cpu_and_memory(row["CPU"], row["RAM"]), axis=1)
        
        server_per_timestep = server_df[server_df["Time Step"] > 0].groupby(["Time Step"])["Normalized Utilization"].mean()

        # Persisting information
        server_data[labels[index].capitalize()] = server_per_timestep

        # Closing file
        server_file.close()

    return pd.concat(server_data, axis=1)

# %% [markdown]
# ### Provisioning Time per Time Step

# %%
def get_provisioning_time_per_time_step_data():
    service_data = {}

    for index, log in enumerate(logs[:4]):
        # Opening file
        service_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/Service.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/Service.msgpack"
        )
        service_file = open(service_msgpack_file, "rb")
        service_msgpack = msgpack.load(service_file)
        service_df = pd.DataFrame(service_msgpack)

        # Collecting information
        prov_time_per_timestep = service_df[service_df["Time Step"] > 0].groupby(["Time Step"])["Migrations Duration"].apply(sum).apply(lambda x: sum(x) / len(x) if len(x) > 0 else 0)

        # Persisting information
        service_data[labels[index].capitalize()] = prov_time_per_timestep

        # Closing file
        service_file.close()

    prov_time_per_timestep_df = pd.concat(service_data, axis=1)

    return prov_time_per_timestep_df

# %% [markdown]
# ### Service Reallocations per Time Step

# %%
def get_service_reallocations_per_time_step_data(wo_cache = False):
    service_data = {}

    for index, log in enumerate(logs[:4]):
        # Opening file
        service_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/Service.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/Service.msgpack"
        )
        service_file = open(service_msgpack_file, "rb")
        service_msgpack = msgpack.load(service_file)
        service_df = pd.DataFrame(service_msgpack)

        # Collecting information
        key = "Number of Finished Migrations Without Using Cache" if wo_cache else "Number of Finished Migrations"
        service_reallocations_per_timestep = service_df[service_df["Time Step"] > 0].groupby(["Time Step"])[key].sum()

        # Persisting information
        service_data[labels[index].capitalize()] = service_reallocations_per_timestep

        # Closing file
        service_file.close()

    service_reallocations_per_timestep_df = pd.concat(service_data, axis=1)

    return service_reallocations_per_timestep_df

# %% [markdown]
# ### Latency per Time Step

# %%
def get_latency_per_time_step_data():
    user_data = {}

    for index, log in enumerate(logs[:4]):
        # Opening file
        user_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/User.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/User.msgpack"
        )
        user_file = open(user_msgpack_file, "rb")
        user_msgpack = msgpack.load(user_file)
        user_df = pd.DataFrame(user_msgpack)

        # Collecting information
        latency_per_timestep = user_df[user_df["Time Step"] > 0].groupby(["Time Step"])["Delays"].mean()

        # Persisting information
        user_data[labels[index].capitalize()] = latency_per_timestep

        # Closing file
        user_file.close()

    latency_per_timestep_df = pd.concat(user_data, axis=1)

    return latency_per_timestep_df

# %% [markdown]
# ### Plot Data

# %%
def calculate_x(x, width, i, n):
    return x + width * (i - n / 2) + width / 2


def plot_data_with_grouped_bar(
    keys: list,
    data: pd.DataFrame,
    xlabel: str,
    ylabel: str,
    bbox_to_anchor: tuple,
    yscale: str = "linear",
    yticks: list = None,
):
    # Removing data from resource aware algorithm executions
    data = data[data["dataset"].apply(lambda x: "resource_aware_dynamic" not in x)]

    # Plotting bar chart
    fig, ax = plt.subplots(figsize=(10, 6))

    width = 0.8

    hatches = ["", "/", "|", "\\", "x", "o"]

    x = np.arange(len(data))

    for key in keys:
        ax.bar(
            x=calculate_x(x, width/len(keys), keys.index(key), len(keys)),
            height=data[key],
            width=width/len(keys),
            label=key.title(),
            hatch=hatches.pop(0),
            color="#aaaaaa",
            edgecolor="black",
            linewidth=2,
            error_kw={"elinewidth": 2, "capthick": 2, "capsize": 5}
        )

    # Setting labels and ticks
    ax.legend(fontsize=20, bbox_to_anchor=bbox_to_anchor, loc="upper center", ncol=2)
    ax.set_xlabel(xlabel, fontsize=24, fontweight="bold", labelpad=10)
    ax.set_ylabel(ylabel, fontsize=24, fontweight="bold", labelpad=10, loc="center")
    ax.set_xticks(x, labels)
    ax.tick_params(axis="x", labelsize=24)
    ax.tick_params(axis="y", labelsize=24)
    ax.set_yscale(yscale)
    if yscale == "log":
        ax.set_yticks(yticks)
        ax.get_yaxis().set_major_formatter(mtick.ScalarFormatter())
    if ylabel == "% of Steps Active":
        ax.get_yaxis().set_major_formatter(mtick.PercentFormatter(1.0, decimals=0))

    # Saving figure
    plt.tight_layout()
    plt.show()

# %%
def plot_data_over_time(
    labels: list,
    data: pd.DataFrame,
    xlabel: str,
    ylabel: str,
    bbox_to_anchor,
):    
    fig, ax = plt.subplots(figsize=(10, 6))

    ax.set_xlabel(xlabel, fontsize=24, fontweight="bold", labelpad=10)
    ax.set_ylabel(ylabel, fontsize=24, fontweight="bold", labelpad=10, loc="center")
    ax.tick_params(axis="x", labelsize=24)
    ax.tick_params(axis="y", labelsize=24)

    p = ax.plot(
        data,
        linewidth=2,
    )

    # Adding legend
    ax.legend(labels, fontsize=20, bbox_to_anchor=bbox_to_anchor, loc="upper center", ncol=3)

    # Saving figure
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Results

# %%
base_dir = "logs"

last_step = 3600

logs = [
    ("central", "central;nodes=196"),
    ("community", "community;nodes=196"),
    ("p2p", "p2p;nodes=196"),
    ("dynamic", "p2p;nodes=196"),
    ("dynamic_enhanced", "p2p;nodes=196"),
    ("resource_aware_dynamic", "p2p;nodes=196", "1", "0.5"),
    ("resource_aware_dynamic", "p2p;nodes=196", "1", "0.6"),
    ("resource_aware_dynamic", "p2p;nodes=196", "1", "0.7"),
    ("resource_aware_dynamic", "p2p;nodes=196", "1", "0.8"),
    ("resource_aware_dynamic", "p2p;nodes=196", "1", "0.9"),
    ("resource_aware_dynamic", "p2p;nodes=196", "1", "1.0"),
    ("resource_aware_dynamic", "p2p;nodes=196", "2", "0.5"),
    ("resource_aware_dynamic", "p2p;nodes=196", "2", "0.6"),
    ("resource_aware_dynamic", "p2p;nodes=196", "2", "0.7"),
    ("resource_aware_dynamic", "p2p;nodes=196", "2", "0.8"),
    ("resource_aware_dynamic", "p2p;nodes=196", "2", "0.9"),
    ("resource_aware_dynamic", "p2p;nodes=196", "2", "1.0"),
    ("resource_aware_dynamic", "p2p;nodes=196", "3", "0.5"),
    ("resource_aware_dynamic", "p2p;nodes=196", "3", "0.6"),
    ("resource_aware_dynamic", "p2p;nodes=196", "3", "0.7"),
    ("resource_aware_dynamic", "p2p;nodes=196", "3", "0.8"),
    ("resource_aware_dynamic", "p2p;nodes=196", "3", "0.9"),
    ("resource_aware_dynamic", "p2p;nodes=196", "3", "1.0"),
]

seed = "1"

labels = ["Central", "Community", "P2P", "Dynamic", "Dynamic Enh."]

# %% [markdown]
# ### Latency

# %%
latency_df = get_latency_data()

# %%
latency_df
# Out:
#                                             dataset       mean  median   p95  \
# 0                      (central, central;nodes=196)  20.684293    20.0  30.0
# 1                  (community, community;nodes=196)  20.843125    20.0  30.0
# 2                              (p2p, p2p;nodes=196)  21.971262    20.0  40.0
# 3                          (dynamic, p2p;nodes=196)  21.056499    20.0  30.0
# 4                 (dynamic_enhanced, p2p;nodes=196)  20.807870    20.0  30.0
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  20.779124    20.0  30.0
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  20.772116    20.0  30.0
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  20.794484    20.0  30.0
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  20.841780    20.0  30.0
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  20.925372    20.0  30.0
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  21.731442    20.0  40.0
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  20.788214    20.0  30.0
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  20.821213    20.0  30.0
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  20.813424    20.0  30.0
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  20.966073    20.0  30.0
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  21.145862    20.0  30.0
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  21.731442    20.0  40.0
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  20.951038    20.0  30.0
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  21.035585    20.0  30.0
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  21.149334    20.0  30.0
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  21.368695    20.0  30.0
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  21.559636    20.0  40.0
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  21.731442    20.0  40.0
#
#      geo_mean
# 0   19.532095
# 1   19.643268
# 2   20.503567
# 3   19.801066
# 4   19.598878
# 5   19.640650
# 6   19.635832
# 7   19.625569
# 8   19.661653
# 9   19.726149
# 10  20.306049
# 11  19.608123
# 12  19.637264
# 13  19.603771
# 14  19.757459
# 15  19.852840
# 16  20.306049
# 17  19.741860
# 18  19.805985
# 19  19.875068
# 20  20.039647
# 21  20.195237
# 22  20.306049

# %%
plot_data_with_grouped_bar(
    ["mean", "median", "p95"],
    latency_df,
    "Registry Provisioning Strategy",
    "Latency",
    (0.5, 1.2)
)

# %% [markdown]
# ### Provisioning Time

# %%
provisioning_time_df = get_provisioning_time_data(last_step)

# %%
provisioning_time_df
# Out:
#                                             dataset       mean  median    p95  \
# 0                      (central, central;nodes=196)  11.404959     9.0  32.75
# 1                  (community, community;nodes=196)   7.240896     4.0  20.00
# 2                              (p2p, p2p;nodes=196)   5.593195     5.0  15.00
# 3                          (dynamic, p2p;nodes=196)   7.405714     6.0  21.00
# 4                 (dynamic_enhanced, p2p;nodes=196)   6.975342     6.0  19.00
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)   7.227462     6.0  19.00
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)   6.831944     6.0  17.05
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)   6.453125     6.0  16.00
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)   6.126404     5.0  15.00
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)   6.297297     6.0  16.00
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)   5.747826     5.0  14.55
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)   6.302778     5.0  16.00
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)   6.119279     5.0  16.00
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)   6.013947     5.0  16.00
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)   5.974825     6.0  16.00
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)   5.860169     5.0  15.00
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)   5.747826     5.0  14.55
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)   5.912676     5.0  16.00
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)   5.870555     5.0  15.00
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)   5.980057     6.0  15.00
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)   5.812760     5.0  15.00
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)   5.717483     5.0  15.00
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)   5.747826     5.0  14.55
#
#     mean (w/o cache)  geo_mean (w/o cache)   old_mean
# 0          16.267191             12.370355  13.649506
# 1          11.644144              9.726511   8.684137
# 2           8.096360              7.005311   6.795356
# 3          10.388778              8.591470   9.250787
# 4           9.945312              8.339655   8.819509
# 5          10.138132              8.529420   9.492604
# 6           9.607422              8.123721   8.953355
# 7           9.140845              7.734484   8.441105
# 8           8.794355              7.502785   8.042217
# 9           8.907445              7.576766   7.776202
# 10          7.995968              6.865611   7.032053
# 11          8.950690              7.551807   8.076532
# 12          8.685039              7.360776   7.719314
# 13          8.589641              7.314195   7.634363
# 14          8.459406              7.140118   7.751265
# 15          8.364919              7.146766   7.272190
# 16          7.995968              6.865611   7.032053
# 17          8.396000              7.100447   7.784811
# 18          8.388211              7.196935   7.307809
# 19          8.345924              7.132888   7.305041
# 20          8.169591              6.944816   7.251992
# 21          8.159681              6.989370   7.039856
# 22          7.995968              6.865611   7.032053

# %%
plot_data_with_grouped_bar(
    ["mean", "median", "p95", "old_mean"],
    provisioning_time_df,
    "Registry Provisioning Strategy",
    "Provisioning Time",
    (0.5, 1.2)
)

# %% [markdown]
# ### Service Reallocations

# %%
reallocations_df = get_reallocations_data(last_step)

# %%
reallocations_df
# Out:
#                                             dataset  total  w/o cache
# 0                      (central, central;nodes=196)    726        509
# 1                  (community, community;nodes=196)    714        444
# 2                              (p2p, p2p;nodes=196)    676        467
# 3                          (dynamic, p2p;nodes=196)    700        499
# 4                 (dynamic_enhanced, p2p;nodes=196)    730        512
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)    721        514
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)    720        512
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)    704        497
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)    712        496
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)    703        497
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)    690        496
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)    720        507
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)    721        508
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)    717        502
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)    715        505
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)    708        496
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)    690        496
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)    710        500
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)    703        492
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)    702        503
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)    721        513
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)    715        501
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)    690        496

# %%
plot_data_with_grouped_bar(
    ["total", "w/o cache"],
    reallocations_df,
    "Registry Provisioning Strategy",
    "Service Reallocations",
    (0.5, 1.35),
    "log",
    [100, 1000, 10000]
)

# %% [markdown]
# ### Registry Usage

# %%
registry_usage_df = get_registry_usage_data()

# %%
registry_usage_df
# Out:
#                                             dataset      mean    median  \
# 0                      (central, central;nodes=196)  0.795890  0.795890
# 1                  (community, community;nodes=196)  0.173331  0.190919
# 2                              (p2p, p2p;nodes=196)  0.027408  0.019890
# 3                          (dynamic, p2p;nodes=196)  0.068067  0.058333
# 4                 (dynamic_enhanced, p2p;nodes=196)  0.091123  0.070833
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  0.059500  0.048264
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  0.058778  0.047364
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  0.050120  0.038022
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  0.051037  0.033333
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  0.050567  0.035260
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  0.029634  0.024580
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  0.065954  0.042766
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  0.055740  0.041667
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  0.051683  0.038889
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  0.046512  0.032171
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  0.040177  0.030952
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  0.029634  0.024580
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  0.048895  0.033333
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  0.043412  0.033000
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  0.044196  0.032946
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  0.040857  0.029641
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  0.035599  0.029922
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  0.029634  0.024580
#
#          p95
# 0   0.795890
# 1   0.240489
# 2   0.047249
# 3   0.182500
# 4   0.283333
# 5   0.150833
# 6   0.166389
# 7   0.150000
# 8   0.162500
# 9   0.133333
# 10  0.048829
# 11  0.262222
# 12  0.153000
# 13  0.142143
# 14  0.166250
# 15  0.083718
# 16  0.048829
# 17  0.122222
# 18  0.120556
# 19  0.114722
# 20  0.114792
# 21  0.076859
# 22  0.048829

# %%
plot_data_with_grouped_bar(
    ["mean", "median", "p95"],
    registry_usage_df,
    "Registry Provisioning Strategy",
    "% of Steps Active",
    (0.5, 1.2),
)

# %% [markdown]
# ### Number of Registries per Time Step

# %%
number_of_registries_df = get_number_of_registries_data()

# %%
plot_data_over_time(
    labels,
    number_of_registries_df,
    "Time Steps",
    "Number of Registries",
    (0.5, 1.2)
)

# %% [markdown]
# ### Server Utilization per Time Step

# %%
server_utilization_df = get_server_utilization_data()

# %%
plot_data_over_time(
    labels,
    server_utilization_df,
    "Time Steps",
    "Server Utilization",
    (0.5, 1.2)
)

# %% [markdown]
# ### Provisioning Time per Time Step

# %%
provisioning_time_per_time_step_df = get_provisioning_time_per_time_step_data()
# Out:
# /tmp/ipykernel_454306/4206513679.py:16: FutureWarning: The provided callable <built-in function sum> is currently using np.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.sum instead.
#   prov_time_per_timestep = service_df[service_df["Time Step"] > 0].groupby(["Time Step"])["Migrations Duration"].apply(sum).apply(lambda x: sum(x) / len(x) if len(x) > 0 else 0)

# %%
plot_data_over_time(
    labels,
    provisioning_time_per_time_step_df,
    "Time Steps",
    "Mean Prov. Time",
    (0.5, 1.2)
)

# %% [markdown]
# ### Service Reallocations per Time Step

# %% [markdown]
# #### Total

# %%
total_service_reallocations_per_timestep_df = get_service_reallocations_per_time_step_data(wo_cache=False)

# %%
plot_data_over_time(
    labels,
    total_service_reallocations_per_timestep_df,
    "Time Steps",
    "Service Reallocations",
    (0.5, 1.2)
)

# %% [markdown]
# #### Without Cache

# %%
service_reallocations_wo_cache_per_timestep_df = get_service_reallocations_per_time_step_data(wo_cache=True)

# %%
plot_data_over_time(
    labels,
    service_reallocations_wo_cache_per_timestep_df,
    "Time Steps",
    "Service Reallocations (W/O Cache)",
    (0.5, 1.2)
)

# %% [markdown]
# ### Latency per Time Step

# %%
latency_per_time_step_df = get_latency_per_time_step_data()

# %%
plot_data_over_time(
    labels,
    latency_per_time_step_df,
    "Time Steps",
    "Latency",
    (0.5, 1.2)
)

# %% [markdown]
# ### Cost Function

# %%
cost_function_df = pd.concat([latency_df["dataset"], latency_df["mean"], provisioning_time_df["mean"]], axis=1, keys=["Dataset", "Latency", "Provisioning Time"])

# %%
# testing different weights for the cost function
weights = np.arange(0, 1.1, 0.1)
cost_function_data = []

for weight in weights:
    cost_function_df["Cost"] = cost_function_df["Latency"] * weight + cost_function_df["Provisioning Time"] * (1 - weight)
    print(f"Weight: {weight}")
    print(cost_function_df.sort_values(by=["Cost"])[["Dataset", "Cost"]])
# Out:
# Weight: 0.0
#                                             Dataset       Cost
# 2                              (p2p, p2p;nodes=196)   5.593195
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)   5.717483
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)   5.747826
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)   5.747826
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)   5.747826
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)   5.812760
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)   5.860169
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)   5.870555
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)   5.912676
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)   5.974825
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)   5.980057
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)   6.013947
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)   6.119279
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)   6.126404
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)   6.297297
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)   6.302778
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)   6.453125
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)   6.831944
# 4                 (dynamic_enhanced, p2p;nodes=196)   6.975342
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)   7.227462
# 1                  (community, community;nodes=196)   7.240896
# 3                          (dynamic, p2p;nodes=196)   7.405714
# 0                      (central, central;nodes=196)  11.404959
# Weight: 0.1
#                                             Dataset       Cost
# 2                              (p2p, p2p;nodes=196)   7.231002
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)   7.301698
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)   7.346188
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)   7.346188
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)   7.346188
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)   7.368354
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)   7.387058
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)   7.388739
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)   7.416512
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)   7.473950
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)   7.493895
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)   7.496985
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)   7.589472
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)   7.597942
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)   7.751321
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)   7.760105
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)   7.887261
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)   8.225962
# 4                 (dynamic_enhanced, p2p;nodes=196)   8.358595
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)   8.582628
# 1                  (community, community;nodes=196)   8.601119
# 3                          (dynamic, p2p;nodes=196)   8.770793
# 0                      (central, central;nodes=196)  12.332892
# Weight: 0.2
#                                             Dataset       Cost
# 2                              (p2p, p2p;nodes=196)   8.868809
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)   8.885913
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)   8.903561
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)   8.917308
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)   8.920348
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)   8.923947
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)   8.944549
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)   8.944549
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)   8.944549
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)   8.973075
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)   8.973842
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)   9.013912
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)   9.059666
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)   9.069480
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)   9.199865
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)   9.222912
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)   9.321397
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)   9.619979
# 4                 (dynamic_enhanced, p2p;nodes=196)   9.741848
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)   9.937794
# 1                  (community, community;nodes=196)   9.961342
# 3                          (dynamic, p2p;nodes=196)  10.135871
# 0                      (central, central;nodes=196)  13.260826
# Weight: 0.30000000000000004
#                                             Dataset       Cost
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  10.420064
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  10.424185
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  10.445877
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  10.453790
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  10.470129
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  10.472199
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  10.479541
# 2                              (p2p, p2p;nodes=196)  10.506615
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  10.529859
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  10.530840
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  10.541017
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  10.542911
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  10.542911
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  10.542911
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  10.648409
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  10.685720
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  10.755533
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  11.013996
# 4                 (dynamic_enhanced, p2p;nodes=196)  11.125101
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  11.292960
# 1                  (community, community;nodes=196)  11.321565
# 3                          (dynamic, p2p;nodes=196)  11.500950
# 0                      (central, central;nodes=196)  14.188759
# Weight: 0.4
#                                             Dataset       Cost
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  11.928021
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  11.933738
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  11.936567
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  11.971324
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  11.974447
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  12.000052
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  12.012555
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  12.035134
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  12.047768
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  12.054344
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  12.096952
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  12.141272
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  12.141272
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  12.141272
# 2                              (p2p, p2p;nodes=196)  12.144422
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  12.148527
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  12.189669
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  12.408013
# 4                 (dynamic_enhanced, p2p;nodes=196)  12.508354
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  12.648127
# 1                  (community, community;nodes=196)  12.681788
# 3                          (dynamic, p2p;nodes=196)  12.866028
# 0                      (central, central;nodes=196)  15.116693
# Weight: 0.5
#                                             Dataset       Cost
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  13.413686
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  13.431857
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  13.453070
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  13.470246
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  13.470449
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  13.484092
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  13.503016
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  13.545496
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  13.564695
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  13.590728
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  13.611335
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  13.623805
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  13.638559
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  13.739634
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  13.739634
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  13.739634
# 2                              (p2p, p2p;nodes=196)  13.782229
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  13.802030
# 4                 (dynamic_enhanced, p2p;nodes=196)  13.891606
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  14.003293
# 1                  (community, community;nodes=196)  14.042011
# 3                          (dynamic, p2p;nodes=196)  14.231107
# 0                      (central, central;nodes=196)  16.044626
# Weight: 0.6000000000000001
#                                             Dataset       Cost
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  14.893633
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  14.935693
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  14.940439
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  14.955630
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  14.969573
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  14.969574
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  14.994040
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  15.031585
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  15.057941
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  15.074142
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  15.081623
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  15.146321
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  15.196048
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  15.222775
# 4                 (dynamic_enhanced, p2p;nodes=196)  15.274859
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  15.337996
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  15.337996
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  15.337996
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  15.358459
# 1                  (community, community;nodes=196)  15.402234
# 2                              (p2p, p2p;nodes=196)  15.420036
# 3                          (dynamic, p2p;nodes=196)  15.596185
# 0                      (central, central;nodes=196)  16.972560
# Weight: 0.7000000000000001
#                                             Dataset       Cost
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  16.373581
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  16.410633
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  16.427167
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  16.439529
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  16.442583
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  16.468699
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  16.486076
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  16.492076
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  16.536950
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  16.560154
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  16.590065
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  16.598551
# 4                 (dynamic_enhanced, p2p;nodes=196)  16.658112
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  16.701915
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  16.713625
# 1                  (community, community;nodes=196)  16.762457
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  16.806990
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  16.936357
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  16.936357
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  16.936357
# 3                          (dynamic, p2p;nodes=196)  16.961264
# 2                              (p2p, p2p;nodes=196)  17.057842
# 0                      (central, central;nodes=196)  17.900493
# Weight: 0.8
#                                             Dataset       Cost
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  17.853529
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  17.880826
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  17.891127
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  17.898705
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  17.926212
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  17.943366
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  17.967823
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  17.984082
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  17.999757
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  18.002579
# 4                 (dynamic_enhanced, p2p;nodes=196)  18.041365
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  18.068791
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  18.088724
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  18.115478
# 1                  (community, community;nodes=196)  18.122679
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  18.257508
# 3                          (dynamic, p2p;nodes=196)  18.326342
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  18.391205
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  18.534719
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  18.534719
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  18.534719
# 2                              (p2p, p2p;nodes=196)  18.695649
# 0                      (central, central;nodes=196)  18.828426
# Weight: 0.9
#                                             Dataset       Cost
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  19.333477
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  19.339671
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  19.351019
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  19.360348
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  19.370243
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  19.378099
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  19.423958
# 4                 (dynamic_enhanced, p2p;nodes=196)  19.424617
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  19.447202
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  19.462565
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  19.466948
# 1                  (community, community;nodes=196)  19.482902
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  19.519082
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  19.617293
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  19.632406
# 3                          (dynamic, p2p;nodes=196)  19.691421
# 0                      (central, central;nodes=196)  19.756360
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  19.813102
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  19.975421
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  20.133080
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  20.133080
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  20.133080
# 2                              (p2p, p2p;nodes=196)  20.333456
# Weight: 1.0
#                                             Dataset       Cost
# 0                      (central, central;nodes=196)  20.684293
# 6   (resource_aware_dynamic, p2p;nodes=196, 1, 0.6)  20.772116
# 5   (resource_aware_dynamic, p2p;nodes=196, 1, 0.5)  20.779124
# 11  (resource_aware_dynamic, p2p;nodes=196, 2, 0.5)  20.788214
# 7   (resource_aware_dynamic, p2p;nodes=196, 1, 0.7)  20.794484
# 4                 (dynamic_enhanced, p2p;nodes=196)  20.807870
# 13  (resource_aware_dynamic, p2p;nodes=196, 2, 0.7)  20.813424
# 12  (resource_aware_dynamic, p2p;nodes=196, 2, 0.6)  20.821213
# 8   (resource_aware_dynamic, p2p;nodes=196, 1, 0.8)  20.841780
# 1                  (community, community;nodes=196)  20.843125
# 9   (resource_aware_dynamic, p2p;nodes=196, 1, 0.9)  20.925372
# 17  (resource_aware_dynamic, p2p;nodes=196, 3, 0.5)  20.951038
# 14  (resource_aware_dynamic, p2p;nodes=196, 2, 0.8)  20.966073
# 18  (resource_aware_dynamic, p2p;nodes=196, 3, 0.6)  21.035585
# 3                          (dynamic, p2p;nodes=196)  21.056499
# 15  (resource_aware_dynamic, p2p;nodes=196, 2, 0.9)  21.145862
# 19  (resource_aware_dynamic, p2p;nodes=196, 3, 0.7)  21.149334
# 20  (resource_aware_dynamic, p2p;nodes=196, 3, 0.8)  21.368695
# 21  (resource_aware_dynamic, p2p;nodes=196, 3, 0.9)  21.559636
# 10  (resource_aware_dynamic, p2p;nodes=196, 1, 1.0)  21.731442
# 16  (resource_aware_dynamic, p2p;nodes=196, 2, 1.0)  21.731442
# 22  (resource_aware_dynamic, p2p;nodes=196, 3, 1.0)  21.731442
# 2                              (p2p, p2p;nodes=196)  21.971262

# %% [markdown]
# ### Checking Coordinates Trace

# %%
labels = ["Central", "Community", "P2P", "Dynamic", "Dynamic Enhanced", "1/0.5", "1/0.6", "1/0.7", "1/0.8", "1/0.9", "1/1.0", "2/0.5", "2/0.6", "2/0.7", "2/0.8", "2/0.9", "2/1.0", "3/0.5", "3/0.6", "3/0.7", "3/0.8", "3/0.9", "3/1.0"]

def get_coordinates_trace_data():
    user_data = {}

    random_user_id = None

    for index, log in enumerate(logs):
        # Opening file
        user_msgpack_file = (
            f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed}/User.msgpack"
            if len (log) == 2
            else f"{base_dir}/algorithm={log[0]};dataset={log[1]};seed={seed};replicas={log[2]};percentage={log[3]}/User.msgpack"
        )
        user_file = open(user_msgpack_file, "rb")
        user_msgpack = msgpack.load(user_file)
        user_df = pd.DataFrame(user_msgpack)

        # Getting random user id
        if random_user_id is None:
            random_user_id = user_df["Object"].sample().iloc[0]

        # Collecting information
        coordinates_trace = user_df[user_df["Object"] == random_user_id][["Coordinates"]]

        # Persisting information
        user_data[f"{labels[index].capitalize()} (User {random_user_id})"] = coordinates_trace

        # Closing file
        user_file.close()

    coordinates_trace_df = pd.concat(user_data, axis=1)

    return coordinates_trace_df

# %%
coordinates_trace_df = get_coordinates_trace_data()

# %%
# check if the coordinates are the same for all algorithms
coordinates_are_the_same = True
for i in range(len(coordinates_trace_df.columns) - 1):
    if not coordinates_trace_df.iloc[:, i].equals(coordinates_trace_df.iloc[:, i + 1]):
        coordinates_are_the_same = False
        break

if coordinates_are_the_same:
    print("Coordinates are the same for all algorithms")
else:
    print("Coordinates are not the same for all algorithms")
# Out:
# Coordinates are the same for all algorithms
